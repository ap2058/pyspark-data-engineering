# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName("dataframe").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.101:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv("cus.csv",header=True,inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +----------+---------+---+-------+----------------+
# |First Name|Last Name|Age|Country|           Email|
# +----------+---------+---+-------+----------------+
# |   Aashish| Pokharel| 24|  Nepal| user1@gmail.com|
# |       Ram|   Sharma| 30|  India| user2@gmail.com|
# |      Sita|      Rai| 22|  Nepal| user3@gmail.com|
# |      John|      Doe| 28|    USA| user4@gmail.com|
# |      Hari|     Lama| 35|  Nepal| user5@gmail.com|
# |      Alex|    Smith| 40|     UK| user6@gmail.com|
# |      Rita|   Gurung| 27|  Nepal| user7@gmail.com|
# |     Sunil|    Thapa| 31|  Nepal| user8@gmail.com|
# |      Maya|    Karki| 26|  Nepal| user9@gmail.com|
# |     David|      Lee| 29|    USA|user10@gmail.com|
# |   Aashish| Pokharel| 45|  Nepal|user11@gmail.com|
# |       Ram|   Sharma| 33|  India|user12@gmail.com|
# |      Sita|      Rai| 21|  Nepal|user13@gmail.com|
# |      John|      Doe| 38|    USA|user14@gmail.com|
# |      Hari|     Lama| 41|  Nepal|user15@gmail.com|
# ...

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- First Name: string (nullable = true)
#  |-- Last Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)

# %%
df_pyspark=spark.read.csv("cus.csv",header=True,inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +----------+---------+---+-------+----------------+
# |First Name|Last Name|Age|Country|           Email|
# +----------+---------+---+-------+----------------+
# |   Aashish| Pokharel| 24|  Nepal| user1@gmail.com|
# |       Ram|   Sharma| 30|  India| user2@gmail.com|
# |      Sita|      Rai| 22|  Nepal| user3@gmail.com|
# |      John|      Doe| 28|    USA| user4@gmail.com|
# |      Hari|     Lama| 35|  Nepal| user5@gmail.com|
# |      Alex|    Smith| 40|     UK| user6@gmail.com|
# |      Rita|   Gurung| 27|  Nepal| user7@gmail.com|
# |     Sunil|    Thapa| 31|  Nepal| user8@gmail.com|
# |      Maya|    Karki| 26|  Nepal| user9@gmail.com|
# |     David|      Lee| 29|    USA|user10@gmail.com|
# |   Aashish| Pokharel| 45|  Nepal|user11@gmail.com|
# |       Ram|   Sharma| 33|  India|user12@gmail.com|
# |      Sita|      Rai| 21|  Nepal|user13@gmail.com|
# |      John|      Doe| 38|    USA|user14@gmail.com|
# |      Hari|     Lama| 41|  Nepal|user15@gmail.com|
# ...

# %%
df_pyspark=spark.read.csv("cus.csv",header=True,inferSchema=True)

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- First Name: string (nullable = true)
#  |-- Last Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Email: string (nullable = true)

# %%
df_pyspark.columns
# Out:
# ['First Name', 'Last Name', 'Age', 'Country', 'Email']

# %%
df_pyspark.head(10)
# Out:
# [Row(First Name='Aashish', Last Name='Pokharel', Age=24, Country='Nepal', Email='user1@gmail.com'),
#  Row(First Name='Ram', Last Name='Sharma', Age=30, Country='India', Email='user2@gmail.com'),
#  Row(First Name='Sita', Last Name='Rai', Age=22, Country='Nepal', Email='user3@gmail.com'),
#  Row(First Name='John', Last Name='Doe', Age=28, Country='USA', Email='user4@gmail.com'),
#  Row(First Name='Hari', Last Name='Lama', Age=35, Country='Nepal', Email='user5@gmail.com'),
#  Row(First Name='Alex', Last Name='Smith', Age=40, Country='UK', Email='user6@gmail.com'),
#  Row(First Name='Rita', Last Name='Gurung', Age=27, Country='Nepal', Email='user7@gmail.com'),
#  Row(First Name='Sunil', Last Name='Thapa', Age=31, Country='Nepal', Email='user8@gmail.com'),
#  Row(First Name='Maya', Last Name='Karki', Age=26, Country='Nepal', Email='user9@gmail.com'),
#  Row(First Name='David', Last Name='Lee', Age=29, Country='USA', Email='user10@gmail.com')]

# %%
df_pyspark.select(['First Name','Last Name']).show(20)
# Out:
# +----------+---------+
# |First Name|Last Name|
# +----------+---------+
# |   Aashish| Pokharel|
# |       Ram|   Sharma|
# |      Sita|      Rai|
# |      John|      Doe|
# |      Hari|     Lama|
# |      Alex|    Smith|
# |      Rita|   Gurung|
# |     Sunil|    Thapa|
# |      Maya|    Karki|
# |     David|      Lee|
# |   Aashish| Pokharel|
# |       Ram|   Sharma|
# |      Sita|      Rai|
# |      John|      Doe|
# |      Hari|     Lama|
# |      Alex|    Smith|
# |      Rita|   Gurung|
# |     Sunil|    Thapa|
# |      Maya|    Karki|
# |     David|      Lee|
# +----------+---------+
# only showing top 20 rows

# %%
df_pyspark.dtypes
# Out:
# [('First Name', 'string'),
#  ('Last Name', 'string'),
#  ('Age', 'int'),
#  ('Country', 'string'),
#  ('Email', 'string')]

# %%
df_pyspark.describe()
# Out:
# DataFrame[summary: string, First Name: string, Last Name: string, Age: string, Country: string, Email: string]

# %%
df_pyspark.describe().show()
# Out:
# +-------+----------+---------+----------------+-------+-----------------+
# |summary|First Name|Last Name|             Age|Country|            Email|
# +-------+----------+---------+----------------+-------+-----------------+
# |  count|       100|      100|             100|    100|              100|
# |   mean|      NULL|     NULL|           32.35|   NULL|             NULL|
# | stddev|      NULL|     NULL|6.58951570084761|   NULL|             NULL|
# |    min|   Aashish|      Doe|              20|  India|user100@gmail.com|
# |    max|     Sunil|    Thapa|              45|    USA|  user9@gmail.com|
# +-------+----------+---------+----------------+-------+-----------------+

# %%
df_pyspark=df_pyspark.withColumn('age after 2 years',df_pyspark['Age']+2)

# %%
df_pyspark.show()
# Out:
# +----------+---------+---+-------+----------------+-----------------+
# |First Name|Last Name|Age|Country|           Email|age after 2 years|
# +----------+---------+---+-------+----------------+-----------------+
# |   Aashish| Pokharel| 24|  Nepal| user1@gmail.com|               26|
# |       Ram|   Sharma| 30|  India| user2@gmail.com|               32|
# |      Sita|      Rai| 22|  Nepal| user3@gmail.com|               24|
# |      John|      Doe| 28|    USA| user4@gmail.com|               30|
# |      Hari|     Lama| 35|  Nepal| user5@gmail.com|               37|
# |      Alex|    Smith| 40|     UK| user6@gmail.com|               42|
# |      Rita|   Gurung| 27|  Nepal| user7@gmail.com|               29|
# |     Sunil|    Thapa| 31|  Nepal| user8@gmail.com|               33|
# |      Maya|    Karki| 26|  Nepal| user9@gmail.com|               28|
# |     David|      Lee| 29|    USA|user10@gmail.com|               31|
# ...

# %%
df_pyspark=df_pyspark.drop('Age')

# %%
df_pyspark.show()
# Out:
# +----------+---------+-------+----------------+-----------------+
# |First Name|Last Name|Country|           Email|age after 2 years|
# +----------+---------+-------+----------------+-----------------+
# |   Aashish| Pokharel|  Nepal| user1@gmail.com|               26|
# |       Ram|   Sharma|  India| user2@gmail.com|               32|
# |      Sita|      Rai|  Nepal| user3@gmail.com|               24|
# |      John|      Doe|    USA| user4@gmail.com|               30|
# |      Hari|     Lama|  Nepal| user5@gmail.com|               37|
# |      Alex|    Smith|     UK| user6@gmail.com|               42|
# |      Rita|   Gurung|  Nepal| user7@gmail.com|               29|
# |     Sunil|    Thapa|  Nepal| user8@gmail.com|               33|
# |      Maya|    Karki|  Nepal| user9@gmail.com|               28|
# |     David|      Lee|    USA|user10@gmail.com|               31|
# |   Aashish| Pokharel|  Nepal|user11@gmail.com|               47|
# ...

# %%
df_pyspark = df_pyspark.withColumnRenamed('age after 2 years', 'Age')

# %%
df_pyspark.show()
# Out:
# +----------+---------+-------+----------------+---+
# |First Name|Last Name|Country|           Email|Age|
# +----------+---------+-------+----------------+---+
# |   Aashish| Pokharel|  Nepal| user1@gmail.com| 26|
# |       Ram|   Sharma|  India| user2@gmail.com| 32|
# |      Sita|      Rai|  Nepal| user3@gmail.com| 24|
# |      John|      Doe|    USA| user4@gmail.com| 30|
# |      Hari|     Lama|  Nepal| user5@gmail.com| 37|
# |      Alex|    Smith|     UK| user6@gmail.com| 42|
# |      Rita|   Gurung|  Nepal| user7@gmail.com| 29|
# |     Sunil|    Thapa|  Nepal| user8@gmail.com| 33|
# |      Maya|    Karki|  Nepal| user9@gmail.com| 28|
# |     David|      Lee|    USA|user10@gmail.com| 31|
# |   Aashish| Pokharel|  Nepal|user11@gmail.com| 47|
# |       Ram|   Sharma|  India|user12@gmail.com| 35|
# |      Sita|      Rai|  Nepal|user13@gmail.com| 23|
# |      John|      Doe|    USA|user14@gmail.com| 40|
# |      Hari|     Lama|  Nepal|user15@gmail.com| 43|
# ...
